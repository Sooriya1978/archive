# %%
import intersections

# %%
xspace = linspace(-10,10,200)
g1,g1p = intersections.g1vals(xspace)
g2,g2p = intersections.g2vals(xspace)

# %%
plt.figure(1)
plt.clf()
plt.plot(xspace,g1,'b-')
plt.plot(xspace,g2,'b-')
plt.savefig('intersections.png')
# WE can see 4 plots
